# %%
import pandas as pd
df = pd.read_csv("Multiclass Clothing Sales Dataset.csv")

# %%
df.shape
# Out:
# (100000, 20)

# %%
df.head()
# Out:
#    Product_Category         Brand  Product_Name Gender Size   Color  \
# 0  Traditional Wear    Forever 21          Tops  Women    S   White
# 1        Athleisure  Ralph Lauren  Casual Shirt    Men  XXL  Yellow
# 2         Outerwear          Nike        Blazer    Men    S   Green
# 3        Athleisure          Zara      Leggings  Women    M   White
# 4        Athleisure          Zara         Dress    Men   XL  Yellow
#
#        Season Payment_Method Customer_Type  Selling_Price   Cost_Price  \
# 0      Winter           Card           New    1817.433878   816.027585
# 1  All-Season           Card     Returning    1672.038198   793.236861
# 2  All-Season            UPI     Returning    1381.568069   890.469629
# 3      Winter            UPI     Returning     859.507388  1497.080062
# 4      Summer    Net Banking     Returning    1642.176945   896.187442
#
#    Discount_Percentage  Quantity_Sold   Total_Sales  Stock_Availability  \
# ...

# %%
df.dtypes
# Out:
# Product_Category        object
# Brand                   object
# Product_Name            object
# Gender                  object
# Size                    object
# Color                   object
# Season                  object
# Payment_Method          object
# Customer_Type           object
# Selling_Price          float64
# Cost_Price             float64
# Discount_Percentage    float64
# Quantity_Sold            int64
# Total_Sales            float64
# Stock_Availability     float64
# Customer_Age           float64
# Purchase_Frequency     float64
# Store_Rating           float64
# Return_Rate            float64
# Sales_Category          object
# dtype: object
